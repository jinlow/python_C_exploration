# %%
x = [1, 2, 3, 4, 5, 6]
y = [1, 2, 3, 4, 5, 6]

# %%
b0 = 0
b1 = 0
alpha = 0.01
epoch = 1000
a_d = 0
for i in range(0,len(x)*epoch):
    idx = i % len(x)
    p = b0 + b1 * x[idx]
    err = p - y[idx]
    b0 = b0 - alpha * err
    b1 = b1 - alpha * err * x[idx]

# %%
b0, b1
# Out:
# (2.7066679155470135e-06, 0.9999994410229337)

# %%
import seaborn as sns

# %%
sns.lineplot(x=range(0,len(x)*epoch), y=var)
# Out:
# /Users/jameskatieinlow/code/c_py_test/cpy_venv/lib/python3.8/site-packages/matplotlib/ticker.py:2039: RuntimeWarning: overflow encountered in multiply
#   steps = self._extended_steps * scale
